# %%
from pathlib import Path
import pandas as pd
import numpy as np

# %%
MEEI_path = Path('../data/raw/')
pat_info = pd.read_excel(MEEI_path/"pat_info.xlsx", sheet_name='Sheet1')

# %%
#pat_info
def get_path(cat, subcat, num):
    if cat == 'Normal':
        return Path(MEEI_path/cat/(cat+str(num)))
    return Path(MEEI_path/cat/(subcat+cat)/(subcat+cat+str(num)))

def get_hb(cat, sub):
    if cat == 'Normal':
        return 1
    elif sub == 'NearNormal':
        return 2
    elif sub == 'Mild':
        return 3
    elif sub == 'Moderate':
        return 4
    elif sub == 'Severe':
        return 5
    elif sub == 'Complete':
        return 6
    else:
        return 0

# %%
pat_info['Path'] = pat_info.apply(lambda row: get_path(row['Category'],row['Sub-category'],row['#']), axis=1)
pat_info['HB_scale'] = pat_info.apply(lambda row: get_hb(row['Category'],row['Sub-category']), axis=1)
pat_info
# Out:
#       Category Sub-category   #   Side  Gender  Age  \
# 0      Flaccid     Complete   1   Left    Male   54
# 1      Flaccid     Complete   2  Right  Female   16
# 2      Flaccid     Complete   3  Right    Male   38
# 3      Flaccid     Complete   4   Left  Female   31
# 4      Flaccid     Complete   5   Left  Female   52
# 5      Flaccid         Mild   1   Left    Male   72
# 6      Flaccid         Mild   2  Right  Female   55
# 7      Flaccid         Mild   3   Left    Male   75
# 8      Flaccid     Moderate   1   Left    Male   51
# 9      Flaccid     Moderate   3   Left  Female   62
# 10     Flaccid     Moderate   4  Right    Male   21
# 11     Flaccid     Moderate   5  Right  Female   64
# 12     Flaccid   NearNormal   1   Left  Female   39
# 13     Flaccid   NearNormal   2  Right  Female   53
# 14     Flaccid   NearNormal   4   Left    Male   30
# 15     Flaccid   NearNormal   5  Right    Male   47
# 16     Flaccid       Severe   1   Left    Male   46
# 17     Flaccid       Severe   2   Left  Female   58
# 18     Flaccid       Severe   3  Right  Female   28
# 19     Flaccid       Severe   5   Left  Female   50
# 20      Normal          NaN   1    NaN    Male   75
# 21      Normal          NaN   2    NaN    Male   36
# 22      Normal          NaN   3    NaN    Male   29
# 23      Normal          NaN   4    NaN  Female   24
# 24      Normal          NaN   5    NaN  Female   35
# 25      Normal          NaN   6    NaN  Female   33
# 26      Normal          NaN   7    NaN  Female   48
# 27      Normal          NaN   8    NaN    Male   33
# 28      Normal          NaN   9    NaN  Female   92
# 29      Normal          NaN  10    NaN    Male   27
# 30  Synkinetic     Complete   1  Right  Female   61
# 31  Synkinetic     Complete   2   Left  Female   68
# 32  Synkinetic     Complete   3  Right  Female   36
# 33  Synkinetic     Complete   4   Left    Male   55
# 34  Synkinetic         Mild   1   Left    Male   50
# 35  Synkinetic         Mild   2  Right    Male   77
# 36  Synkinetic         Mild   3  Right  Female   77
# 37  Synkinetic         Mild   5   Left  Female   53
# 38  Synkinetic     Moderate   1  Right  Female   59
# 39  Synkinetic     Moderate   2  Right  Female   60
# 40  Synkinetic     Moderate   3   Left  Female   58
# 41  Synkinetic     Moderate   5   Left    Male   42
# 42  Synkinetic   NearNormal   1  Right  Female   58
# 43  Synkinetic   NearNormal   2   Left  Female   46
# 44  Synkinetic   NearNormal   3  Right  Female   48
# 45  Synkinetic   NearNormal   4  Right    Male   35
# 46  Synkinetic   NearNormal   5   Left    Male   40
# 47  Synkinetic       Severe   1  Right  Female   28
# 48  Synkinetic       Severe   2   Left  Female   30
# 49  Synkinetic       Severe   3  Right    Male   50
# 50  Synkinetic       Severe   4  Right    Male   76
#
#                                                  Path  HB_scale
# 0   ../data/raw/Flaccid/CompleteFlaccid/CompleteFl...         6
# 1   ../data/raw/Flaccid/CompleteFlaccid/CompleteFl...         6
# 2   ../data/raw/Flaccid/CompleteFlaccid/CompleteFl...         6
# 3   ../data/raw/Flaccid/CompleteFlaccid/CompleteFl...         6
# 4   ../data/raw/Flaccid/CompleteFlaccid/CompleteFl...         6
# 5        ../data/raw/Flaccid/MildFlaccid/MildFlaccid1         3
# 6        ../data/raw/Flaccid/MildFlaccid/MildFlaccid2         3
# 7        ../data/raw/Flaccid/MildFlaccid/MildFlaccid3         3
# 8   ../data/raw/Flaccid/ModerateFlaccid/ModerateFl...         4
# 9   ../data/raw/Flaccid/ModerateFlaccid/ModerateFl...         4
# 10  ../data/raw/Flaccid/ModerateFlaccid/ModerateFl...         4
# 11  ../data/raw/Flaccid/ModerateFlaccid/ModerateFl...         4
# 12  ../data/raw/Flaccid/NearNormalFlaccid/NearNorm...         2
# 13  ../data/raw/Flaccid/NearNormalFlaccid/NearNorm...         2
# 14  ../data/raw/Flaccid/NearNormalFlaccid/NearNorm...         2
# 15  ../data/raw/Flaccid/NearNormalFlaccid/NearNorm...         2
# 16   ../data/raw/Flaccid/SevereFlaccid/SevereFlaccid1         5
# 17   ../data/raw/Flaccid/SevereFlaccid/SevereFlaccid2         5
# 18   ../data/raw/Flaccid/SevereFlaccid/SevereFlaccid3         5
# 19   ../data/raw/Flaccid/SevereFlaccid/SevereFlaccid5         5
# 20                         ../data/raw/Normal/Normal1         1
# 21                         ../data/raw/Normal/Normal2         1
# 22                         ../data/raw/Normal/Normal3         1
# 23                         ../data/raw/Normal/Normal4         1
# 24                         ../data/raw/Normal/Normal5         1
# 25                         ../data/raw/Normal/Normal6         1
# 26                         ../data/raw/Normal/Normal7         1
# 27                         ../data/raw/Normal/Normal8         1
# 28                         ../data/raw/Normal/Normal9         1
# 29                        ../data/raw/Normal/Normal10         1
# 30  ../data/raw/Synkinetic/CompleteSynkinetic/Comp...         6
# 31  ../data/raw/Synkinetic/CompleteSynkinetic/Comp...         6
# 32  ../data/raw/Synkinetic/CompleteSynkinetic/Comp...         6
# 33  ../data/raw/Synkinetic/CompleteSynkinetic/Comp...         6
# 34  ../data/raw/Synkinetic/MildSynkinetic/MildSynk...         3
# 35  ../data/raw/Synkinetic/MildSynkinetic/MildSynk...         3
# 36  ../data/raw/Synkinetic/MildSynkinetic/MildSynk...         3
# 37  ../data/raw/Synkinetic/MildSynkinetic/MildSynk...         3
# 38  ../data/raw/Synkinetic/ModerateSynkinetic/Mode...         4
# 39  ../data/raw/Synkinetic/ModerateSynkinetic/Mode...         4
# 40  ../data/raw/Synkinetic/ModerateSynkinetic/Mode...         4
# 41  ../data/raw/Synkinetic/ModerateSynkinetic/Mode...         4
# 42  ../data/raw/Synkinetic/NearNormalSynkinetic/Ne...         2
# 43  ../data/raw/Synkinetic/NearNormalSynkinetic/Ne...         2
# 44  ../data/raw/Synkinetic/NearNormalSynkinetic/Ne...         2
# 45  ../data/raw/Synkinetic/NearNormalSynkinetic/Ne...         2
# 46  ../data/raw/Synkinetic/NearNormalSynkinetic/Ne...         2
# 47  ../data/raw/Synkinetic/SevereSynkinetic/Severe...         5
# 48  ../data/raw/Synkinetic/SevereSynkinetic/Severe...         5
# 49  ../data/raw/Synkinetic/SevereSynkinetic/Severe...         5
# 50  ../data/raw/Synkinetic/SevereSynkinetic/Severe...         5

# %%
# Store the table to a pickle file
pat_info.to_pickle('MEEI_pat_info.pkl')

# %%
class MEEI_Patient:
    def __init__(self, id, pat_info_row):
        super().__init__()
        self._id = id
        self._path = pat_info_row['Path']
        print(self._path)
        # Could potentially also have all the info from pat_info_row here, i.e. side, age, gender, etc.
        
        self._img = np.zeros((8,1080,720,3),dtype=np.uint8) # could potentially use frames from video in the future
        self._landmarks = np.zeros((8,68,2),dtype=np.int16) # only using the default model for now
        #self._dists = np.zeros((8,68,2),dtype=np.int16)
        self._features = np.zeros((8,29),dtype=np.float32)
        self._hb_scale = [pat_info_row['HB_scale'] for i in range(8)]
        
        self.load_imgs()
        self.get_landmarks_features()

    def load_imgs(self):
        img_paths = []
        for x in self._path.iterdir():
            if x.is_file():
                if x.suffix == '.jpg' or x.suffix == '.JPG':
                    img_paths.append(x)
                
        for i in range(len(img_paths)):
            im = cv2.imread(str(img_paths[i]))
            if im.shape[0] != 1080 or im.shape[1] != 720:
                im = cv2.resize(im,(720,1080))
            self._img[i] = im
            
    def get_landmarks_features(self):
        for i in range(8):
            img_lm = GetLandmarks(self._img[i])
            self._landmarks[i] = img_lm._shape
            
            lm_results = ProcessResults(img_lm)
            self._features[i] = lm_results._features_arr # 29 features

# %%
all_pats = np.zeros((len(pat_info)),dtype=object)

for i in range(len(pat_info)):
    all_pats[i] = MEEI_Patient(i, pat_info.loc[i])
# Out:
# ../data/raw/Flaccid/CompleteFlaccid/CompleteFlaccid1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 4
#       1 all_pats = np.zeros((len(pat_info)),dtype=object)
#       3 for i in range(len(pat_info)):
# ----> 4     all_pats[i] = MEEI_Patient(i, pat_info.loc[i])
#
# Cell In[26], line 15, in MEEI_Patient.__init__(self, id, pat_info_row)
#      12 self._features = np.zeros((8,29),dtype=np.float32)
#      13 self._hb_scale = [pat_info_row['HB_scale'] for i in range(8)]
# ---> 15 self.load_imgs()
#      16 self.get_landmarks_features()
#
# Cell In[26], line 26, in MEEI_Patient.load_imgs(self)
#      23             img_paths.append(x)
#      25 for i in range(len(img_paths)):
# ---> 26     im = cv2.imread(str(img_paths[i]))
#      27     if im.shape[0] != 1080 or im.shape[1] != 720:
#      28         im = cv2.resize(im,(720,1080))
#
# NameError: name 'cv2' is not defined

# %%
all_pats[30]._id

# %%
all_ids = np.concatenate([np.full((8), i) for i in range(len(pat_info))])
all_imgs = np.concatenate([all_pats[x]._img for x in range(len(all_pats))]) 
all_lms = np.concatenate([all_pats[x]._landmarks for x in range(len(all_pats))]) 
all_features = np.concatenate([all_pats[x]._features for x in range(len(all_pats))]) 
all_hb = np.concatenate([all_pats[x]._hb_scale for x in range(len(all_pats))])

all_pats_processed_data = [all_ids, all_imgs, all_lms, all_features, all_hb]

# %%
# Store the processed data to a pickle file
with open('all_pats_processed_data.pickle', 'wb') as f:
    pickle.dump(all_pats_processed_data, f)

# %%
arr_info(all_ids)
