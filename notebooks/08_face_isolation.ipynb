# %%
import sys
from pathlib import Path
import cv2
from PIL import Image
from IPython.display import display

# Go up one level from notebooks/ → project_root/
PROJECT_ROOT = Path().resolve().parent
sys.path.append(str(PROJECT_ROOT))

# %%
from src.preprocessing.face_isolation import *

# %%
DATA_DIR = PROJECT_ROOT / "data"
IMG_PATH = DATA_DIR / "raw" / "Flaccid" / "CompleteFlaccid" / "CompleteFlaccid4" / "CompleteFlaccid4_3.jpg"
OUT_PATH = DATA_DIR / "debug_face_224_aligned.jpg"

# %%
ok = isolate_face_to_224(IMG_PATH, OUT_PATH, target_size=224)

print("Success:", ok)
print("Output:", OUT_PATH)

display(Image.open(OUT_PATH))
# Out:
# Success: True
# Output: /Users/willcrosswhite/Documents/All_Code/Palsy/palsy-detection-main/data/debug_face_224_aligned.jpg
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1774401419.411548       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 90.5), renderer: Apple M4 Pro
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224>
